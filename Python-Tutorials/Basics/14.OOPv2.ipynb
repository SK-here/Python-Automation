# %% [markdown]
# # Object Oriented Programming
# In a **Fast and Furi`OOPs`** Way!!!

# %% [markdown]
# **Principles of OOPs**
# - Classes
# - Objects
# - Attributes & Methods
# - Constructors & Desctructors
# - Encapsulation
# - Abstraction
# - Polymorphism
# - Inheritance
# - Magic Methods ( `__init__`, `__str__`)
# - Multiple Inheritence
# - Mixins: An art to design specific patterns, that enables specific behaviors to classes.
# - Composition
# - Design Patterns:

# %% [markdown]
# ## Classes

# %% [markdown]
# In computer programming classes are like a blueprint to define the objects. Classes are used to define the various properties (attributes) and behviour (methods) that the objects created from the class will have.
#
# Now, let's take an classic example always used to understand OOPs. A `Car` as an object. To tell a computer what Car actually is... we need to define a class named Car

# %%
# Syntax to define class 
class Car: 
    pass

# %% [markdown]
# **Note** The `pass` keyword is used to define the empty class or method that can be modified later

# %% [markdown]
# Since, we've defined the car now let's have a peek at our garage and see all the parked cars

# %%
# Creatig an object
Toyota_Camry = Car()

BMW_M5 = Car()

Scorpio_N = Car()

# %% [markdown]
# ## Constructors

# %% [markdown]
# Constructor is a special method that runs automatically by calling method `__init__` when an object is created, Basically it's responsible for creating an object and allocating the data /attributes to (initializing) it.
#
# Basically,
# 1. It creates memory for the object
# 2. Initializes it's attributes
#
# Without Constructors, If we try to create an object, it will give error as below:

# %%
class Car:
    pass

bmw = Car()

print(bmw.brand)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 6
#       2     pass
#       3
#       4 bmw = Car()
#       5
# ----> 6 print(bmw.brand)
#
# AttributeError: 'Car' object has no attribute 'brand'

# %% [markdown]
# Now, that we've an object's blueprint, We also need a data (or attributes) to define it's various properties such as the color, variant, moodel, type, etc.

# %%
class Car:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year

# %% [markdown]
# ### The Initialization of object
# Notice in above snippet we've *`__init__`* an special python method with soul purpose to initialize an object after it is created by assigining initial values to it.

# %% [markdown]
# Say in our example

# %%
bmw = Car("BMW", "M5 Competition", 2025)

# %% [markdown]
# Python automatically runs the `__init__(...)` to store

# %% [markdown]
# ```python
# brand = "BMW"
# model = "M5 Competition"
# year  = 2025
# ```

# %% [markdown]
# #### The *`self`* game

# %% [markdown]
# Notice in the same snippet, there's an additional keyword argument *`self`* was passed along with the 'brand', 'model', 'year'. Here, self refers to the current object.
#
# Suppose,

# %% [markdown]
# class Car:
#     def __init__(self, brand, model, year):
#         self.brand = brand

# %% [markdown]
# Python secretly does...
# ```python
# Car.__init__(bmw, "BMW")
# ```
#
# So, `self` becomes 'bmw'
#
# Translating
#
# ```python
# self.brand  = brand
# ```
# into,
# ```python
# bmw.brand = "BMW"
# ```

# %% [markdown]
# Here's How it works, Suppose for below code snippet...
#
# ```python
# class Car:
#
#     def __init__(self):
#
#         print("Car initialized")
#
# bmw = Car()
# ```
#
# 1. Allocates Memory -> Create an empty space in memory
# 2. Creates an empty object
# 3. Automatically, Executes `__init__()` block
# 4. Run the object and assign data to the  attributes
#
# Internally, python does something similar to...
#
# ```python
# bmw = Car.__new__(Car)
#
# Car.__init__(bmw)
# ```

# %% [markdown]
# Internally It will look like this...
#
#
# ```txt
# bmw = Car("BMW", "M5 Competition")
#         |
#         v
# 1. Create memory
#         |
#         v
# 2. Create empty object
#         |
#         v
# 3. Run __init__()
#         |
#         v
# 4. Store data
#
# brand = BMW
#
# model = M5 Competition
#         |
#         v
# 5. Return object
#         |
#         v
# bmw
# ```

# %% [markdown]
# ##  Destructor

# %% [markdown]
# #### What is a destructor?
#
# A destructor is a special method called using `__del__()` that Python calls when an object is about to be destroyed. It is mainly used for cleanup tasks such as releasing resources, closing files, or closing database connections. However, its execution time is not guaranteed.
#
# Unlike contructors destructors are not used very often as python alraedy has it's own garbacge collection mechanish that decides when to remove and object from memory. And by it's nature, as long as even a single reference is present for a particular object it python does not delete the object from a memory it just deletes the particular reference for a particular object.
#
# Example.

# %%
class Car:
    def __init__(self):
        self.friend = None
    
    def __del__(self):
        print("Destroyed")

car1 = Car()

car2 = Car()

car1.friend = car2

car2.friend = car1

# %%
del car1
del car2

# %% [markdown]
# As long as even a single reference is present for a object (in above case it's a circular reference) It does may delay the cleanup. Determining the time it wil take to clean up is undefined as program may can crash before it happens.

# %% [markdown]
# Now the question rises if we want to clean up the resourses how can we do it?
#
# So the answer is simple, Python also provides the way to explicity deal with such situations...

# %%
class Car:
    def close(self):
        close_operation() # It can be renamed

# %% [markdown]
# Basically, `__del__()` is not guaranteed to execute at a specific time because Python uses garbage collection. An object is destroyed only when Python determines that it is no longer needed, and the exact timing depends on references, circular references, interpreter shutdown, and the garbage collector's behavior. Therefore, important cleanup logic should not rely on `__del__()`.

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # Encapsulation

# %% [markdown]
# Now, extending further the exaple of `Car()`, Imagine we're engineers at the "BMW" building software for a BMW M5 Competition. Since it's a mechanical car, so there are some parts of it we need to expose enough, but not everything (especially design and implementation details).
#
# This technique of hiding the implementation details and exposing only what's necessary is called as **Encapsulation**
#
# In other words
# > Bundling the data (attributes) and it's behavhiour (methods) together and controlling how data can be accessed or modified

# %% [markdown]
# In our Car analogy, let's say:
#
# > - You can start the car
# > - You can accelarate or deaccelarate the car
# > - You can aply breaks
# > - You can open/replace/repair few components of car
# > - Or even you can modify few parts of too
#
# But, here's the catch (normall):
#
# > - You cannot modify the ECU
# > - You cannot modify the Feul injectors
# > - You cannot directly alter the ABS Sensors
# > - You cannot directly perform engine tuning
# > - You cannot change the behaviour of sensors
#
# Fo sure you can open the enginer and perform some of the repairs too but it also need to be done in a certain defined way (Unless you're a expert car mechanic with years of experience with same class of cars even still you cannot change certain things a good mechanic will know this 😌)
#
# The car hasa exposed only the safe interface to you. Similarly,

# %% [markdown]
# Let's take an example

# %%
# Speed of BMW
class Car:
    def __init__(self):
        self.speed = 0

# %% [markdown]
# Assuming that the code is exposed, some random developer

# %%
bmw = Car()
bmw.speed = -60

# %% [markdown]
# Now, the BMW Speed = -60 mph
# or worse

# %%
bmw.speed = 1000

# %% [markdown]
# Now, te BMW speed = 1000 mph.
#
# Does, that makes any sense? No right?
#
# Not mechanically, Not Computationally. resulting in corrupted object.

# %% [markdown]
# Now, from a developer's prespective

# %% [markdown]
# #### Imagine you're working at Amazon.
#
# **You expose:**
#
# - create_order()
# - cancel_order()
# - refund_order()
#
# **You never expose:**
#
# - database_connection
# - payment_gateway_secret
# - internal_cache
# - encryption_key
#
# Because users should not directly manipulate internals.

# %% [markdown]
# ### How encapsulation works?
#
# Encapsulation has 3 levels
# - pubic
# - private
# - protected

# %% [markdown]
# #### Public
# By default every class in python is public class

# %%
class Car:
    def __init__(self):
        self.brand = "BMW"

# Accessible anywhere
bmw = Car()
bmw.brand
# Out:
# 'BMW'

# %% [markdown]
# ### Protected
#
# Protected methods/attributes are supposed to be used inside the classes not outside of it.
#
# In python we use `_` (underscore) as a prefix in method's or attribute names.

# %%
class Car:
    def __init__(self):
        self._fuel = 60

# %% [markdown]
# Accessible anywhere but it's a developers agreement that says 'I trust you but do not touch this directly' However, It's not a restriction

# %%
bmw = Car()
bmw._fuel
# Out:
# 60

# %%
bmw._fuel = 50

bmw._fuel
# Out:
# 50

# %% [markdown]
# Unlike C++ or Java where protected methods or Data/attributes are not accessible outside the class, In python It's just a notation to point the developers that the method or attribute should not be used outside the class. However, Python does allows it. We've already seen in above example.

# %% [markdown]
# ### Private

# %% [markdown]
# In python private methods/attributes denoted using `__` double underscores and it is also accessible like protected, However, python uses a trick called `name mangling` to at least disable direct access to the code.
#
# Let's see this in action.

# %%
class Car:
    def __init__(self):
        self.__engine_temp = 90

# %%
bmw = Car()

bmw.__engine_temp # Attribute Error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 3
#       1 bmw = Car()
#       2
# ----> 3 bmw.__engine_temp # Attribute Error
#
# AttributeError: 'Car' object has no attribute '__engine_temp'

# %% [markdown]
# Now, let's see name mangling in action...

# %% [markdown]
# ```python
# # Python changes the code from
# self.__engine_temp
#
# # to the code
# self._Car__engine_temp
# ```
#
# Disabling direct access to the method/attrib. But it can be accessed using

# %%
bmw._Car__engine_temp
# Out:
# 90

# %% [markdown]
# Now, let's try to modify it a bit

# %%
bmw._Car__engine_temp = 95
bmw._Car__engine_temp
# Out:
# 95

# %% [markdown]
# As you can see we've already modified the private method too... However, as a developers good practice it is highly advised not to do that since these notations are used industry wide and by doing to even as a experiment while working pn a Enterprise results will be unpredictable or entire might break.
#
# ## Why Python did this?
# > Answer is simple - ***To avoid accidental modification and standardize the code modification not to provide military grade security.***
#
# Expose carefully,

# %% [markdown]
# ### Proper Way to Interact using encapsulation

# %%
class Car:
    def __init__(self):
        self.__speed = 0

    def accelarate(self):
        self.__speed += 20

    def get_speed(self):
        return self.__speed

# %%
bmw = Car()
bmw.accelarate()

print (bmw.get_speed())
# Out:
# 20

# %% [markdown]
# ### Getters and Setters (older method)

# %%
# Getters
def get_speed(self):
    return self.__speed

# %%
# Setters
def set_speed(self, speed):
    if 0 <= speed <= 300:
        self.__speed = speed

# %% [markdown]
# ### Python Way of doing it e.g. `@property`

# %%
class Car:
    
    def __init__(self):
        self.__speed = 0

    @property
    def speed(self):
        return self.__speed

    @speed.setter
    def speed(self, value):
        if 0 <= value <= 300:
            self.__speed = value

# %% [markdown]
# **Usage**

# %%
bmw = Car()
bmw.speed = 150
print(bmw.speed)
# Out:
# 150

# %% [markdown]
# This code defines a `Car` class with a private attribute `__speed`. The `@property` decorator allows you to access `__speed` as if it were a public attribute since it's a private attribute it is easily accessible within the class, while the `@speed.setter` decorator allows you to set the value of `__speed` with some validation. Specifically, the setter only allows values between `0` and `300` to be assigned to `__speed`.

# %% [markdown]
# #### Under the hood

# %% [markdown]
# When you write
#
# ```python
# bmw.speed = 150
#
# # Python scretly does
# bmw.speed.setter(150)
#
# # when you read
# print(bmw.speed)
#
# # python secretly does
# bmw.speed()
#
# ```

# %% [markdown]
# #### When to use ENCAPSULATION

# %% [markdown]
# - [x] Sensitive Data Exists
# - [x] Validation is Required
# - [x] Business Rules Exists
# - [x] Internal Implementation may change
# - [x] Multiple developers work together
# - [x] API Design
# - [x] Enterprise Application
#
# ##### Examples:
# - Banking apps
# - SOC dashboards
# - E-commerce
# - Hospital systems
# - Payment systems
# - Authentication systems
# - Cloud platforms

# %% [markdown]
# Avoid overengineering or use for tiny scripts or simple automations.

# %% [markdown]
# ##### BAD Encapsulation

# %%
class Car:
    def __init__(self):
        self.__speed = 0

# %% [markdown]
# Then,

# %%
bmw.__Car__speed = 500

# %% [markdown]
# Developer bypassed your rule, Never Trust encapsulation for security. Alway validate what you put and ask why you put it there?

# %% [markdown]
# ***At the very bottom in Python, Encapsulation is the process of building the data and methods together inside a class and restricting direct access to sensitive data by exposing controlled interfaces.***

# %% [markdown]
# **Mental Model**
#
# ```txt
# BMW M5 Competition
#
#         User
#          |
#          |
#      Press Button
#      Accelerate()
#      Brake()
#      Fuel Level()
#          |
#          |
# -----------------------
# |    Encapsulation    |
# -----------------------
#          |
#        Engine
#         ECU
#         ABS
#        Turbo
#     Fuel Injector
#       Sensors
#     Internal Logic
# ```
#
# **Golden rule:** Don't expose your engine. Expose your steering wheel.

# %% [markdown]
# **Summary:** Encapsulation
#
# ```txt
# _  = Protected (convention)
#
# __ = Private (name mangling)
#
# @property = Pythonic getter/setter
#
# Encapsulation ≠ Security
#
# Encapsulation = Controlled access
#
# Don't overuse getters/setters
#
# Use encapsulation where business rules matter
# ```

# %% [markdown]
# Next topic in our BMW software company would naturally be Abstraction, because once we protect the engine (encapsulation), we can start hiding the complexity of how the engine works (abstraction).

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # Abstraction
